# %% [markdown]
# \\\FCYT ORO VERDE - INTELIGENCIA ARTFICIAL  - 2023 - ALGORITMOS GENETICOS<br>
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
# Hadad, A - Diaz, SR
#
# ![image.png](data:image/png;base64,...)

# %%
# Python3 program to create target string, starting from
# random string using Genetic Algorithm
import random
# Number of individuals in each generation
POPULATION_SIZE = 100
# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}''' #about it, you create combinations.
# Target string to be generated
TARGET = "hola a todos!"

f(x,y) >

f(x1,x2,x3,x4,x5,x6,x7,x8,x9)





F(W)

# %%
class Individual(object):
    '''
      Class representing individual in population
    '''
    def __init__(self, chromosome):
        self.chromosome = chromosome  # 1 chromosome for each ind
        self.fitness = self.cal_fitness() #1 fitness value for each ind
    '''
      Though classmethod and staticmethod are quite similar,
      there's a slight difference in usage for both entities:
      classmethod must have a reference to a class object as the first parameter,
      whereas staticmethod can have no parameters at all.
    '''
    @classmethod
    def mutated_genes(self):
        '''
          create random genes for mutation
        '''
        global GENES
        gene = random.choice(GENES)  #function to select a random item from a list and other sequence types
        return gene

    @classmethod
    def create_gnome(self): #string of genes /chromosome/
        '''
          create chromosome or string of genes
        '''
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)] # create string with random choice, the size is equal to len(TARGET)

    def mate(self, par2): # (offspring) - return the best?.
        '''
          Perform mating and produce new offspring (descendencia)
        '''
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome): # abc - ebb   (a,e),(b,b),(c,b)       ...The zip() function takes iterables (can be zero or more), aggregates them in a tuple, and return it.
            # random probability
            prob = random.random()
            # if prob is less than 0.45, insert gene
            # from parent 1
            if prob < 0.45: # p<0.45, gp1.
                child_chromosome.append(gp1)
            # if prob is between 0.45 and 0.90, insert
            # gene from parent 2
            elif prob < 0.90: # p<0.9, gp2.
                child_chromosome.append(gp2)

            # otherwise insert random gene(mutate),

            # for maintaining diversity, insert random mutation
            else:
                child_chromosome.append(self.mutated_genes()) #create new.

        # create new Individual(offspring) using
        # generated chromosome for offspring
        return Individual(child_chromosome)

    #the fitness function compute the difference between the target and the chromosome.
    def cal_fitness(self):
        '''
          Calculate fittness score, it is the number ofs
          characters in string which differ from target
          string.
        '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):    #  EFC    ABC , fitness = 2
            if gs != gt:
               fitness+= 1 # what means high fitness?
        return fitness

# %%
# Driver code
def main():
    global POPULATION_SIZE
    #current generation
    generation = 1
    found = False
    population = []

    # create initial population /random/
    for _ in range(POPULATION_SIZE):
                gnome = Individual.create_gnome() #devuelve un string, aleatoreo... de tamaño len(TARGET).
                Individuo = Individual(gnome)
                population.append(Individuo)

    while not found:
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0: #if the element with less fitness in the population is the solution, break.
            found = True
            break

        # Otherwise generate new offsprings for new generation
        new_generation = []
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100) # 10%
        new_generation.extend(population[:s]) #select the s best of the old population.

        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50]) # c1  p
            parent2 = random.choice(population[:50]) # c2  m
            child = parent1.mate(parent2)
            new_generation.append(child)

        population = new_generation

        print("Generation: {}\tString: {}\tFitness: {}".\
              format(generation,
              "".join(population[0].chromosome),
              population[0].fitness))

        generation += 1


    print("Generation: {}\tString: {}\tFitness: {}".\
          format(generation,
          "".join(population[0].chromosome),
          population[0].fitness))

# %%
if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: Pf4a)A}1o8KuR	Fitness: 11
# Generation: 2	String: Pf4a)A}1o8KuR	Fitness: 11
# Generation: 3	String: h.$]kt F;toje	Fitness: 10
# Generation: 4	String: !ou/_a Uo/NSa	Fitness: 9
# Generation: 5	String: N/da)a Qo/ohf	Fitness: 8
# Generation: 6	String: ho%N a QZ/o[[	Fitness: 7
# Generation: 7	String: ho%a a}QZxos[	Fitness: 6
# Generation: 8	String: ho%a a tqxOs[	Fitness: 5
# Generation: 9	String: ho:a a toco;W	Fitness: 4
# Generation: 10	String: ho:a a toco;W	Fitness: 4
# Generation: 11	String: ho%a a toKos[	Fitness: 3
# Generation: 12	String: ho%a a toKos[	Fitness: 3
# Generation: 13	String: ho%a a toKos[	Fitness: 3
# Generation: 14	String: ho%a a toKos!	Fitness: 2
# Generation: 15	String: ho%a a toKos!	Fitness: 2
# Generation: 16	String: ho%a a toKos!	Fitness: 2
# Generation: 17	String: ho%a a toKos!	Fitness: 2
# Generation: 18	String: ho%a a toKos!	Fitness: 2
# Generation: 19	String: hola a tofos!	Fitness: 1
# Generation: 20	String: hola a tofos!	Fitness: 1
# ...
